# %%
import pandas as pd
import glob
import numpy as np

# %%
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df[["Survived"]])
# Out:
# pandas.core.frame.DataFrame

# %%
maledf = df[['Sex']] == 'male'
femaledf = df[['Sex']] == 'female'
ageMask = df['Age'] > 29.0

print('male: ', maledf.shape[0])
print('female: ', femaledf.shape[0])
# Out:
# male:  183
# female:  183

# %%
maledf = df['Sex'] == 'male'
femaledf = df['Sex'] == 'female'
sobreviveu = df['Survived'] == 1

# %%
mulheresVivas = df[sobreviveu & femaledf].shape[0]
homensVivos = df[sobreviveu & maledf].shape[0]

# %%
print('Mulheres vivas: ', mulheresVivas/ df.shape[0])
print('Homens vivos: ', homensVivos/ df.shape[0])
# Out:
# Mulheres vivas:  0.44808743169398907
# Homens vivas:  0.22404371584699453
